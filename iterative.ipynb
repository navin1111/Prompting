# %%
!  pip install -q litellm

# %%
from litellm import completion
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
def get_completion(prompt , model ='gpt-3.5-turbo'):
    messages = [{'role':'user','content': prompt}]
    response = completion(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %%
fact_sheet_chair = """
Sure, here's a fact sheet for a chair:

Chair Fact Sheet

Overview:
The chair is a versatile piece of furniture designed for sitting, providing comfort, and supporting various activities such as dining, working, or relaxing. It typically consists of a seat, backrest, and legs, although designs can vary widely.

Construction:
The chair's construction involves assembling various components such as the seat, backrest, and legs using joinery techniques like mortise and tenon, dowels, or screws. The frame can be made of wood, metal, or plastic, while the seat and backrest may feature upholstery for added comfort.

Dimensions:
The dimensions of a chair can vary depending on its intended use and design. Common dimensions include seat height, width, and depth, as well as backrest height and overall height. Standard chair heights range from 16 to 18 inches for dining chairs and 18 to 20 inches for desk chairs.

Options:
Chairs come in a wide range of styles and configurations to suit different needs and preferences. Options include armrests or armless designs, adjustable height or tilt mechanisms for ergonomic support, and various upholstery choices such as fabric, leather, or mesh.

Materials:
Chairs can be constructed from a variety of materials, including:

Wood: Commonly used for traditional and modern designs, offering durability and aesthetic appeal.
Metal: Provides strength and stability, often used for contemporary or industrial-style chairs.
Plastic: Lightweight and affordable, suitable for outdoor or casual seating.
Upholstery: Fabrics, leathers, and synthetic materials add comfort and style to chairs, with options for customization.
Country of Origin:
Chairs are manufactured in countries around the world, with production centers in regions known for their expertise in furniture craftsmanship and manufacturing. Common countries of origin include China, Italy, the United States, and Scandinavian countries like Denmark and Sweden."""

# %%
prompt = f""" your task is to help the marketing team create a description for a retail website for a product based on a technical fact sheet .  write a product description base the information provided in the technical specifications delimited by triple backtips.  technical specifications : ''' {fact_sheet_chair}''' """

# %%
print(get_completion(prompt))
# Out:
# Introducing our versatile and comfortable chair, perfect for any setting!
#
# Constructed with precision and care, our chair features a sturdy frame made of high-quality materials such as wood, metal, or plastic. The seat and backrest are designed for maximum comfort, with the option for added upholstery for a touch of luxury.
#
# With customizable dimensions to fit your needs, our chair comes in a variety of styles and configurations. Choose from armrests or armless designs, adjustable height mechanisms, and a range of upholstery choices including fabric, leather, or mesh.
#
# Crafted with expertise from around the world, our chair is a testament to quality and craftsmanship. Whether you're dining, working, or relaxing, our chair is the perfect choice for any space. Upgrade your seating experience with our chair today!

# %%
fact_sheet_chair = """
Sure, here's a fact sheet for a chair:

Chair Fact Sheet

Overview:
The chair is a versatile piece of furniture designed for sitting, providing comfort, and supporting various activities such as dining, working, or relaxing. It typically consists of a seat, backrest, and legs, although designs can vary widely.

Construction:
The chair's construction involves assembling various components such as the seat, backrest, and legs using joinery techniques like mortise and tenon, dowels, or screws. The frame can be made of wood, metal, or plastic, while the seat and backrest may feature upholstery for added comfort.

Dimensions:
The dimensions of a chair can vary depending on its intended use and design. Common dimensions include seat height, width, and depth, as well as backrest height and overall height. Standard chair heights range from 16 to 18 inches for dining chairs and 18 to 20 inches for desk chairs.

Options:
Chairs come in a wide range of styles and configurations to suit different needs and preferences. Options include armrests or armless designs, adjustable height or tilt mechanisms for ergonomic support, and various upholstery choices such as fabric, leather, or mesh.

Materials:
Chairs can be constructed from a variety of materials, including:

Wood: Commonly used for traditional and modern designs, offering durability and aesthetic appeal.
Metal: Provides strength and stability, often used for contemporary or industrial-style chairs.
Plastic: Lightweight and affordable, suitable for outdoor or casual seating.
Upholstery: Fabrics, leathers, and synthetic materials add comfort and style to chairs, with options for customization.
Country of Origin:
Chairs are manufactured in countries around the world, with production centers in regions known for their expertise in furniture craftsmanship and manufacturing. Common countries of origin include China, Italy, the United States, and Scandinavian countries like Denmark and Sweden."""

# %%
prompt = f""" your task is to help the marketing team create a description for a retail website for a product based on a technical fact sheet .  write a product description base the information provided in the technical specifications delimited by triple backtips. Format everything as HTML that can be used in a website. Place the description in a <div> element  technical specifications :  ''' {fact_sheet_chair}''' """

# %%
print(get_completion(prompt))
# Out:
# ```html
# <div>
#   <h2>Chair Fact Sheet</h2>
#
#   <h3>Overview:</h3>
#   <p>The chair is a versatile piece of furniture designed for sitting, providing comfort, and supporting various activities such as dining, working, or relaxing. It typically consists of a seat, backrest, and legs, although designs can vary widely.</p>
#
#   <h3>Construction:</h3>
#   <p>The chair's construction involves assembling various components such as the seat, backrest, and legs using joinery techniques like mortise and tenon, dowels, or screws. The frame can be made of wood, metal, or plastic, while the seat and backrest may feature upholstery for added comfort.</p>
#
#   <h3>Dimensions:</h3>
#   <p>The dimensions of a chair can vary depending on its intended use and design. Common dimensions include seat height, width, and depth, as well as backrest height and overall height. Standard chair heights range from 16 to 18 inches for dining chairs and 18 to 20 inches for desk chairs.</p>
#
# ...

# %%
from IPython.display import display, HTML

# %%
display(HTML(get_completion(prompt)))
# Out:
# ```html
# <div>
#   <h2>Chair Fact Sheet</h2>
#   <h3>Overview:</h3>
#   <p>The chair is a versatile piece of furniture designed for sitting, providing comfort, and supporting various activities such as dining, working, or relaxing. It typically consists of a seat, backrest, and legs, although designs can vary widely.</p>
#
#   <h3>Construction:</h3>
#   <p>The chair's construction involves assembling various components such as the seat, backrest, and legs using joinery techniques like mortise and tenon, dowels, or screws. The frame can be made of wood, metal, or plastic, while the seat and backrest may feature upholstery for added comfort.</p>
#
#   <h3>Dimensions:</h3>
#   <p>The dimensions of a chair can vary depending on its intended use and design. Common dimensions include seat height, width, and depth, as well as backrest height and overall height. Standard chair heights range from 16 to 18 inches for dining chairs and 18 to 20 inches for desk chairs.</p>
#
# ...
