# %%
!  pip install -q litellm

# %% [markdown]
# ### DELIMETERS

# %%
from litellm import completion
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
def get_completion(prompt , model ='gpt-3.5-turbo'):
    messages = [{'role':'user','content': prompt}]
    response = completion(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %%
text = f"""The morning sun cast its golden rays across the sleepy town, painting the rooftops with hues of amber and tangerine. Birds chirped merrily, their songs echoing through the quiet streets as life began to stir. People emerged from their homes, savoring the crisp freshness of the air as they embarked on their daily routines. Down by the riverbank, a lone fisherman cast his line into the tranquil waters, his mind lost in contemplation. Meanwhile, in the bustling market square, vendors set up their stalls, displaying an array of colorful fruits and vegetables, while the aroma of freshly baked bread wafted through the air. It was a scene of serene beauty, a snapshot of ordinary life unfolding against the backdrop of nature's grandeur."""

prompt = f""" transform the text delimited by triple backticks into a tamil sentence. '''{text}''' 

"""

# %%
print(get_completion(prompt))
# Out:
# காலை சூரியன் அதிசயமான காந்தியை அழகாக பள்ளியில் படித்து, மேல்ந்து மஞ்சள் மற்றும் தேங்காய் நிறங்களுடன் கூடிய கூட்டங்களை ஓவியமாக அழைத்துவிட்டது. பறவைகள் மகிழ்ச்சியாக கூக்குத்தான், அவர்களின் பாடல்கள் அமையும் அமையாத தெருகளில் அலைந்துவிட்டன. மக்கள் தங்கள் வீடுகளிலிருந்து வெளியே வந்து, அவர்கள் தங்கள் தினசரி செயல்களில் ஈடுபட்டுவிட்டனர். நதியோரத்தில், ஒரு தனியாக மீன்காட்டி அவன் மனம் ஆலோசனையில் இழுந்துவிட்டது. இதற்கு எதிர்பார்க்கும் நடுவர் சந்தையில், விற்பனையாளர்கள் தங்கள் கடைகளை அமைத்து, விவசாயிகள் மற்றும் காய்களின் விவரமான பழங்களை காட்டும் போது, புதியவற்றின் வாசனை காற்றில் பரந்தது. இது ஒரு சமாதான அழகுவின் நிழல், இயற்கையின் பெருமையின் எதிர்பார்ப்பின் மேல் நிகழ்ந்த ஒரு சிந்தனையான வார்த்தை.

# %% [markdown]
# ### STRUCTURED OUTPUT

# %%
prompt = f""" provide a details of Davinci code book along with their authors and genres. Provide them in JSON format with the following keys: book_id, title, author, genre."""

# %%
print(get_completion(prompt))
# Out:
# {
#     "books": [
#         {
#             "book_id": 1,
#             "title": "The Da Vinci Code",
#             "author": "Dan Brown",
#             "genre": "Mystery, Thriller"
#         }
#     ]
# }

# %% [markdown]
# ### Condition satisfied or not

# %%
text = f""" After you go to a government office meet the poen and get the receipt and meet the officer if he is available otherwise have your dinner and comeback"""
prompt = f""" you will be provided with text delimited by triple quotes. if it contains a sequence of instrucions,re-write thise instructions in the following format:

step 1 - ....
step 2 - ....

....

step N - ....

if the text does not contain a sequence of instructions , then simply write \"No steps provided.\"

\"\"\"{text}\"\"\"

"""

# %%
print(get_completion(prompt))
# Out:
# step 1 - Go to a government office
# step 2 - Meet the peon and get the receipt
# step 3 - Meet the officer if he is available
# step 4 - Otherwise, have your dinner
# step 5 - Come back

# %% [markdown]
# ### Few shot prompting

# %%
prompt = f"""
your task is to answer in a consistent style.text

<person1>: Hey, how's it going?

<person2>: Not too bad, just trying to stay busy. How about you?

<person1>:Same here, got a lot on my plate these days. Did you catch the game last night?
"""

# %%
print(get_completion(prompt))
# Out:
# <person2>: I did! It was a close one, but our team pulled through in the end. How about you, did you watch it?

# %% [markdown]
# ### Specifying the steps to complete the task

# %%
text= f"""Once upon a time, in a faraway kingdom, there lived a humble blacksmith named Jacob. One day, while wandering in the forest, Jacob stumbled upon a shimmering sword buried beneath an ancient oak tree. Sensing its power, Jacob took the sword and returned to his village. Little did he know, the sword held the key to defeating the tyrant king who ruled over the kingdom with an iron fist. With the help of the sword, Jacob rallied the villagers and led them into battle against the king's army. In a fierce showdown, Jacob wielded the sword with skill and courage, ultimately vanquishing the tyrant and bringing peace to the land. From that day forward, Jacob was hailed as a hero, and the sword became a symbol of hope and freedom for generations to come."""

prompt = f"""
perform the following actions:
1. Summarize the text delimited by triple backticks with 1 sentence.
2. translate the summary into french
3. list each name in the frence summary
4. output a json object that contains the following keys: french_summary , num_names.


use the following format:

Summary:<text to summarize>
Translation: <summary tanslation>
Names: <List of names in italian summary>
Output JSON :<json with summary and num_names>

Text: '''{text}'''
"""

# %%
print(get_completion(prompt))
# Out:
# Summary: In a faraway kingdom, a humble blacksmith named Jacob found a powerful sword that helped him defeat a tyrant king and bring peace to the land.
# Translation: Dans un royaume lointain, un humble forgeron nommé Jacob a trouvé une épée puissante qui l'a aidé à vaincre un roi tyran et à apporter la paix au pays.
# Names: Jacob
# Output JSON: {"french_summary": "Dans un royaume lointain, un humble forgeron nommé Jacob a trouvé une épée puissante qui l'a aidé à vaincre un roi tyran et à apporter la paix au pays.", "num_names": 1}

# %% [markdown]
# ### Model to work on its own solution

# %%
prompt = f""" 
Determine if the solution is correct or not.

Question:
What is the chemical symbol for water?

solution:
 H2O - Water is composed of two hydrogen atoms and one oxygen atom, represented by the chemical formula H2O."""

# %%
print(get_completion(prompt))
# Out:
# The solution is correct. The chemical symbol for water is H2O.

# %%
prompt = f""" 
Determine if the solution is correct or not.

Question:
What is the chemical symbol for water?

solution:
 CO2 - This is the chemical formula for carbon dioxide, which is a different compound composed of one carbon atom and two oxygen atoms."""

# %%
print(get_completion(prompt))
# Out:
# The solution is incorrect. The chemical symbol for water is H2O, which represents two hydrogen atoms and one oxygen atom.
